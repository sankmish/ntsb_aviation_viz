# %%
import config

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
import pymysql
pymysql.install_as_MySQLdb()

# %%
engine1 = create_engine('sqlite:///data/aviation_accidents.sqlite')
engine2 = create_engine(f'mysql://{config.username}:{config.password}@localhost/ntbs_data')

# %%
session1 = Session(bind=engine1)
session2 = Session(bind=engine2)

# %%
# reflect and automap, view existing tables in source db
Base1 = automap_base()
Base1.prepare(engine1,reflect=True)
Base1.classes.keys()
# Out:
# ['accident_coords', 'aviation_accidents', 'aviation_accidents_limited']

# %%
# reflect and automap, view existing tables in source db
Base2 = automap_base()
Base2.prepare(engine2,reflect=True)
Base2.classes.keys()
# Out:
# ['aviation_accidents_coord', 'aviation_cut']

# %%
Accident1 = Base1.classes.aviation_accidents_limited

# %%
results = session1.query(Accident1).all()

# %%
# confirm 11248 results
len(results)
# Out:
# 11248

# %% [markdown]
# #### load limited table

# %%
import pandas as pd

# %%
q = 'SELECT * FROM aviation_accidents_limited'
df = pd.read_sql(q,engine1)

# %%
df.head()
# Out:
#    id         EventId AccidentNumber InvestigationType   EventDate  \
# 0   1  20181116X04602     WPR19FA026          Accident  11/16/2018
# 1   2  20181116X63655     ERA19FA047          Accident  11/16/2018
# 2   3  20181108X13619     WPR19LA021          Accident  11/08/2018
# 3   4  20181112X55458     ERA19WA040          Accident  11/08/2018
# 4   5  20181104X72439     ERA19FA036          Accident  11/04/2018
#
#           Location        Country   Latitude    Longitude AirportCode  \
# 0    Overgaard, AZ  United States  34.405833  -110.524167        AZ82
# 1      Clanton, AL  United States  32.822223   -86.459167        None
# 2      Ontario, CA  United States  34.134722  -117.663333         CCB
# 3  Nassau, Bahamas        Bahamas  25.067223   -77.492222        MYNN
# 4       Louisa, VA  United States  38.024445   -77.960556         LKU
#
#         ...       TotalFatalInjuries TotalSeriousInjuries TotalMinorInjuries  \
# 0       ...                        2                 None               None
# 1       ...                        2                 None               None
# 2       ...                     None                 None               None
# 3       ...                        1                 None               None
# 4       ...                        1                 None               None
#
#   TotalUninjured Schedule PurposeOfFlight BroadPhaseOfFlight WeatherCondition  \
# 0           None     None        Personal           APPROACH              VMC
# 1           None     None     Positioning        MANEUVERING              VMC
# 2              3     None        Personal            DESCENT              VMC
# 3           None     None            None           APPROACH              VMC
# 4           None     None        Personal           APPROACH              VMC
#
#   ReportStatus PublicationDate
# 0  Preliminary      11/28/2018
# 1  Preliminary      11/27/2018
# 2  Preliminary      11/29/2018
# 3      Foreign            None
# 4  Preliminary      11/09/2018
#
# [5 rows x 32 columns]

# %%
len(df.columns)
# Out:
# 32

# %% [markdown]
# #### insert starting coords

# %%
with open('data/lats.txt','r') as file:
    lats = file.read().splitlines()

# %%
with open('data/lons.txt','r') as file:
    lons = file.read().splitlines()

# %%
df.insert(32,'start_lats',lats)
df.insert(33,'start_lons',lons)

# %%
df.head()
# Out:
#    id         EventId AccidentNumber InvestigationType   EventDate  \
# 0   1  20181116X04602     WPR19FA026          Accident  11/16/2018
# 1   2  20181116X63655     ERA19FA047          Accident  11/16/2018
# 2   3  20181108X13619     WPR19LA021          Accident  11/08/2018
# 3   4  20181112X55458     ERA19WA040          Accident  11/08/2018
# 4   5  20181104X72439     ERA19FA036          Accident  11/04/2018
#
#           Location        Country   Latitude    Longitude AirportCode  \
# 0    Overgaard, AZ  United States  34.405833  -110.524167        AZ82
# 1      Clanton, AL  United States  32.822223   -86.459167        None
# 2      Ontario, CA  United States  34.134722  -117.663333         CCB
# 3  Nassau, Bahamas        Bahamas  25.067223   -77.492222        MYNN
# 4       Louisa, VA  United States  38.024445   -77.960556         LKU
#
#         ...       TotalMinorInjuries TotalUninjured Schedule PurposeOfFlight  \
# 0       ...                     None           None     None        Personal
# 1       ...                     None           None     None     Positioning
# 2       ...                     None              3     None        Personal
# 3       ...                     None           None     None            None
# 4       ...                     None           None     None        Personal
#
#   BroadPhaseOfFlight WeatherCondition ReportStatus PublicationDate  \
# 0           APPROACH              VMC  Preliminary      11/28/2018
# 1        MANEUVERING              VMC  Preliminary      11/27/2018
# 2            DESCENT              VMC  Preliminary      11/29/2018
# 3           APPROACH              VMC      Foreign            None
# 4           APPROACH              VMC  Preliminary      11/09/2018
#
#        start_lats      start_lons
# 0       34.571098     -114.358002
# 1     32.61510086    -85.43399811
# 2   39.0041007996  -119.157997131
# 3  Missing Report  Missing Report
# 4     38.00979996     -77.9701004
#
# [5 rows x 34 columns]

# %% [markdown]
# #### limit dataset for nulls

# %%
df2 = df[(df['start_lats'] != 'Missing Report') & \
         (df['start_lats'] != 'NO CODE') & \
         (df['start_lats'] != 'not found')]

# %%
# count rows
len(df2)
# Out:
# 9099

# %%
df2.head()
# Out:
#    id         EventId AccidentNumber InvestigationType   EventDate  \
# 0   1  20181116X04602     WPR19FA026          Accident  11/16/2018
# 1   2  20181116X63655     ERA19FA047          Accident  11/16/2018
# 2   3  20181108X13619     WPR19LA021          Accident  11/08/2018
# 4   5  20181104X72439     ERA19FA036          Accident  11/04/2018
# 5   6  20181104X01658     CEN19FA024          Accident  11/04/2018
#
#         Location        Country   Latitude    Longitude AirportCode  \
# 0  Overgaard, AZ  United States  34.405833  -110.524167        AZ82
# 1    Clanton, AL  United States  32.822223   -86.459167        None
# 2    Ontario, CA  United States  34.134722  -117.663333         CCB
# 4     Louisa, VA  United States  38.024445   -77.960556         LKU
# 5     Uvalde, TX  United States  29.368056   -99.923889        None
#
#           ...         TotalMinorInjuries TotalUninjured Schedule  \
# 0         ...                       None           None     None
# 1         ...                       None           None     None
# 2         ...                       None              3     None
# 4         ...                       None           None     None
# 5         ...                       None           None     None
#
#   PurposeOfFlight BroadPhaseOfFlight WeatherCondition ReportStatus  \
# 0        Personal           APPROACH              VMC  Preliminary
# 1     Positioning        MANEUVERING              VMC  Preliminary
# 2        Personal            DESCENT              VMC  Preliminary
# 4        Personal           APPROACH              VMC  Preliminary
# 5        Personal             CRUISE              VMC  Preliminary
#
#   PublicationDate          start_lats          start_lons
# 0      11/28/2018           34.571098         -114.358002
# 1      11/27/2018         32.61510086        -85.43399811
# 2      11/29/2018       39.0041007996      -119.157997131
# 4      11/09/2018         38.00979996         -77.9701004
# 5      11/13/2018  29.533700942993164  -98.46980285644531
#
# [5 rows x 34 columns]

# %% [markdown]
# #### migrate to MySQL
# - add primary key

# %%
df2.to_sql('coords_with_nulls',con=engine2,if_exists='replace')

# %% [markdown]
# #### migrate to SQLITE
# - insert coordinate table
# - use filter_data.ipynb
